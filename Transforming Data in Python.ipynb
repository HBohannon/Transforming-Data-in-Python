# %% [markdown]
# # Load Packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
from scipy.stats import boxcox

# %% [markdown]
# # Load Data

# %%
Seattle_ParksnRec = pd.read_csv (r'C:/Users/Hanna Bohannon/Documents/DSO105C/DSO105C Datasets/Seattle_ParksnRec.csv')

# %%
Seattle_ParksnRec.head()
# Out:
#   Geographic Region  Year  # of trips Winter  # of participants Winter  \
# 0           Central  2005                 13                       154
# 1           Central  2006                 17                       229
# 2           Central  2007                 17                       222
# 3           Central  2008                 18                       300
# 4           Central  2009                 18                       276
#
#    # of trips Spring  # of participants Spring  # of trips Summer  \
# 0                 18                       290                 20
# 1                 16                       227                 19
# 2                 15                       244                 13
# 3                 19                       335                 20
# 4                 23                       302                 25
#
#    # of participants Summer  # of trips Fall  # of participants Fall  \
# ...

# %% [markdown]
# # Check For Normality

# %%
sns.pairplot(Seattle_ParksnRec)

# %% [markdown]
# # Visualizing Transformations

# %% [markdown]
# # Number of trips Winter

# %%
sns.histplot(Seattle_ParksnRec['# of trips Winter'])
# Out:
# <AxesSubplot:xlabel='# of trips Winter', ylabel='Count'>

# %%
Seattle_ParksnRec['# of trips WinterSQRT'] = np.sqrt(Seattle_ParksnRec['# of trips Winter'])

# %%
Seattle_ParksnRec.head()
# Out:
#   Geographic Region  Year  # of trips Winter  # of participants Winter  \
# 0           Central  2005                 13                       154
# 1           Central  2006                 17                       229
# 2           Central  2007                 17                       222
# 3           Central  2008                 18                       300
# 4           Central  2009                 18                       276
#
#    # of trips Spring  # of participants Spring  # of trips Summer  \
# 0                 18                       290                 20
# 1                 16                       227                 19
# 2                 15                       244                 13
# 3                 19                       335                 20
# 4                 23                       302                 25
#
#    # of participants Summer  # of trips Fall  # of participants Fall  \
# ...

# %% [markdown]
# # Number of participants Winter

# %%
sns.histplot(Seattle_ParksnRec['# of participants Winter'])
# Out:
# <AxesSubplot:xlabel='# of participants Winter', ylabel='Count'>

# %%
Seattle_ParksnRec['# of participants WinterLOG'] = np.log(Seattle_ParksnRec['# of participants Winter'])

# %%
Seattle_ParksnRec.head()
# Out:
#   Geographic Region  Year  # of trips Winter  # of participants Winter  \
# 0           Central  2005                 13                       154
# 1           Central  2006                 17                       229
# 2           Central  2007                 17                       222
# 3           Central  2008                 18                       300
# 4           Central  2009                 18                       276
#
#    # of trips Spring  # of participants Spring  # of trips Summer  \
# 0                 18                 17.029386                 20
# 1                 16                 15.066519                 19
# 2                 15                 15.620499                 13
# 3                 19                 18.303005                 20
# 4                 23                 17.378147                 25
#
#    # of participants Summer  # of trips Fall  # of participants Fall  \
# ...

# %% [markdown]
# # Number of participants Spring

# %%
sns.histplot(Seattle_ParksnRec['# of participants Spring'])
# Out:
# <AxesSubplot:xlabel='# of participants Spring', ylabel='Count'>

# %%
Seattle_ParksnRec['# of participants SpringLOG'] = np.log(Seattle_ParksnRec['# of participants Spring'])

# %%
Seattle_ParksnRec.head()
# Out:
#   Geographic Region  Year  # of trips Winter  # of participants Winter  \
# 0           Central  2005                 13                       154
# 1           Central  2006                 17                       229
# 2           Central  2007                 17                       222
# 3           Central  2008                 18                       300
# 4           Central  2009                 18                       276
#
#    # of trips Spring  # of participants Spring  # of trips Summer  \
# 0                 18                 17.029386                 20
# 1                 16                 15.066519                 19
# 2                 15                 15.620499                 13
# 3                 19                 18.303005                 20
# 4                 23                 17.378147                 25
#
#    # of participants Summer  # of trips Fall  # of participants Fall  ...  \
# ...

# %% [markdown]
# # Number of trips Summer

# %%
sns.histplot(Seattle_ParksnRec['# of trips Summer'])
# Out:
# <AxesSubplot:xlabel='# of trips Summer', ylabel='Count'>

# %%
Seattle_ParksnRec['# of trips SummerSQ'] = Seattle_ParksnRec['# of trips Summer']**2

# %%
Seattle_ParksnRec.head()
# Out:
#   Geographic Region  Year  # of trips Winter  # of participants Winter  \
# 0           Central  2005                 13                       154
# 1           Central  2006                 17                       229
# 2           Central  2007                 17                       222
# 3           Central  2008                 18                       300
# 4           Central  2009                 18                       276
#
#    # of trips Spring  # of participants Spring  # of trips Summer  \
# 0                 18                 17.029386                 20
# 1                 16                 15.066519                 19
# 2                 15                 15.620499                 13
# 3                 19                 18.303005                 20
# 4                 23                 17.378147                 25
#
#    # of participants Summer  # of trips Fall  # of participants Fall  ...  \
# ...

# %% [markdown]
# # Number of participants Summer

# %%
sns.histplot(Seattle_ParksnRec['# of participants Summer'])
# Out:
# <AxesSubplot:xlabel='# of participants Summer', ylabel='Count'>

# %%
Seattle_ParksnRec['# of participants SummerSQRT'] = np.sqrt(Seattle_ParksnRec['# of participants Summer'])

# %%
Seattle_ParksnRec.head()
# Out:
#   Geographic Region  Year  # of trips Winter  # of participants Winter  \
# 0           Central  2005                 13                       154
# 1           Central  2006                 17                       229
# 2           Central  2007                 17                       222
# 3           Central  2008                 18                       300
# 4           Central  2009                 18                       276
#
#    # of trips Spring  # of participants Spring  # of trips Summer  \
# 0                 18                 17.029386                 20
# 1                 16                 15.066519                 19
# 2                 15                 15.620499                 13
# 3                 19                 18.303005                 20
# 4                 23                 17.378147                 25
#
#    # of participants Summer  # of trips Fall  # of participants Fall  \
# ...
